# %% [markdown]
# # 1. Analytics section
#
# Before start analysing of user behavior, we must download all data we need. But we
# First, and foremost I watched analytics section.
#
# Dynamic of ether balance is shown below.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-04-23%20%D0%B2%2010.27.57.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-04-23%20%D0%B2%2010.27.57.png)

# %% [markdown]
# We see that the first replenishment of balance was in August, 4 in 2020 and last transaction was on 18 April, 2022. The maximum balance was achieved on March, 2022. This user incredible increased his balance at the begining of the March. I suspect it could be related with russian special war operation which officially started at 24 February, 2022. But this hypothesis are needed in checking.

# %% [markdown]
# The next step is analysing of transactions dynamic, which is introduced in the plot below.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-04-23%20%D0%B2%2010.46.18.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-04-23%20%D0%B2%2010.46.18.png)

# %% [markdown]
# We can observe that the most frequent transaction periods were periods with the lowest balance.
# Total amount of transactions is 7514.

# %% [markdown]
# Next step is analysis of transfers - as ethers as tokens.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
from dotenv import load_dotenv
load_dotenv()
ETHERSCAN_API_KEY = os.getenv("API_KEY")

# %%
user = "0x99fd1378ca799ed6772fe7bcdc9b30b389518962"
block_start = '10595414'
block_end = '14647406'
query = f"""https://api.etherscan.io/api?module=account&action=txlist&address={user}&startblock={block_start}&endblock={block_end}&page=2&offset=10&sort=asc&apikey={ETHERSCAN_API_KEY}"""
requests.get(query).content
# Out:
# b'{"status":"1","message":"OK","result":[{"blockNumber":"10601650","timeStamp":"1596655931","hash":"0xd31490b64ae0fb298449e377f1eda528224a76e0141b8b4f7fe35ca0faeba36e","nonce":"7","blockHash":"0x7fa25fda3396a52f9bf0eacadf8828f69010ae44fbf71a45f0577c7fc8a28e01","transactionIndex":"103","from":"0x99fd1378ca799ed6772fe7bcdc9b30b389518962","to":"0xeca3c22189e7f0fa551f3f0a2a8897c2102e2f2b","value":"0","gas":"545114","gasPrice":"37000000000","isError":"0","txreceipt_status":"1","input":"...","contractAddress":"","cumulativeGasUsed":"4714281","gasUsed":"387922","confirmations":"4050373"},{"blockNumber":"10602007","timeStamp":"1596660626","hash":"0x7fe8e3188209efd709d94069b9857340bf753f8292e13b3de9a16663694823d3","nonce":"8","blockHash":"0x51343cc7b21ad6bd33604e82be3c9ed89be39edb7cd22c596ebc7bbd8826f270","transactionIndex":"129","from":"0x99fd1378ca799ed6772fe7bcdc9b30b389518962","to":"0x32666b64e9fd0f44916e1378efb2cfa3b3b96e80","value":"0","gas":"236743","gasPrice":"32000000000","isError":"
# ...

# %%
0xd31490b64ae0fb298449e377f1eda528224a76e0141b8b4f7fe35ca0faeba36e
# Out:
# 'https://api.etherscan.io/api?module=account   &action=txlist\n   &address=0x99fd1378ca799ed6772fe7bcdc9b30b389518962\n   &startblock=0\n   &endblock=99999999\n   &page=1\n   &offset=10\n   &sort=asc\n   &apikey=QSJ1D76CKZY7GT1QPB9APJMWI4NVNZS5R8'

# %%
import json
import time

import requests

ADDRESS = "0x99fd1378ca799ed6772fe7bcdc9b30b389518962"

def get_last_block():
    return int(json.loads(requests.get(
        f"https://api.etherscan.io/api?module=block&action=getblocknobytime&timestamp={round(time.time())}&closest=before&apikey={ETHERSCAN_API_KEY}"
    ).text)["result"])

def get_last_txs(since=1):
    return json.loads(requests.get(
        f"https://api.etherscan.io/api?module=account&action=txlist&address={ADDRESS}&startblock={get_last_block() - since}&sort=asc&apikey={ETHERSCAN_API_KEY}"
    ).text)["result"]

txs = get_last_txs()

# %%
get_last_block()
# Out:
# 14651959
